# %% [markdown]
# # Heatmap Demo
# This demo depicts a (literal) heatmap, showing the temperature variation by day and hour throughout the month of May 2017.

# %% [markdown]
# ## Import Dependencies

# %%
from highcharts_maps import constants
from highcharts_core.chart import Chart as CoreChart
from highcharts_maps.chart import Chart
from highcharts_maps.options.series.heatmap import HeatmapSeries
import pandas
import datetime

# %% [markdown]
# ## Prepare the Configuration

# %%
options_kwargs = {
    'chart': {
        'type': 'heatmap',
        'inverted': True
    },

    'accessibility': {
        'description': 'We see how temperatures are warmer during the day, especially from around 9am to 9pm. May 8th through 11th are also overall colder days compared to the rest. Overall the temperatures range from around -1 degrees C to around 23 degrees C.'
    },

    'title': {
        'text': 'Highcharts Heat Map',
        'align': 'left'
    },

    'subtitle': {
        'text': 'Temperature variation by day and hour through May 2017',
        'align': 'left'
    },

    'xAxis': {
        'tickPixelInterval': 50,
        'min': datetime.date(2017, 5, 1),
        'max': datetime.date(2017, 5, 31),
        'labels': {
            'enabled': True,
            'format': '{value:%Y-%m-%d}'
        }
    },

    'yAxis': {
        'accessibility': {
            'description': 'Hours in the day'
        },
        'title': {
            'text': constants.EnforcedNull
        },
        'labels': {
            'format': '{value}:00'
        },
        'minPadding': 0,
        'maxPadding': 0,
        'startOnTick': False,
        'endOnTick': False,
        'tickPositions': [0, 6, 12, 18, 24],
        'tickWidth': 1,
        'min': 0,
        'max': 23
    },

    'colorAxis': {
        'stops': [
            [0, '#3060cf'],
            [0.5, '#fffbbc'],
            [0.9, '#c4463a']
        ],
        'min': -5
    }
}

# %% [markdown]
# ## Populate the Dataframe

# %%
df = pandas.read_csv('temperatures.csv')
df
df.dropna()

#my_chart = Chart.from_csv('temperatures.csv',
#                          wrapper_character = '"')
#my_chart.is_maps_chart=True
#my_chart.display()

# %% [markdown]
# ## Create the Series

# %%
series = HeatmapSeries.from_pandas(df, 
                                   property_map = {'x': 'Date','y': 'Time', 'value': 'Temperature'}, 
                                   series_kwargs = {
                                       'name': 'Temperature',
                                       'borderWidth': 0,
                                       'colsize': 24 * 36e5,
                                       'tooltip': {
                                           'headerFormat': 'Temperature<br/>',
                                           'pointFormat': '{point.x:%e %b, %Y} {point.y}:00: <b>{point.value} ℃</b>'
                                       },
                                       'accessibility': {
                                           'enabled': False
                                       }
                                   })

# %% [markdown]
# ## Assemble the Chart

# %%
chart = Chart(options = options_kwargs)
chart.is_maps_chart = True
chart.add_series(series)

# %% [markdown]
# ## Display the Chart

# %%
ret = chart.display()
print(ret)

as_js_literal = chart.to_js_literal(filename="script.js")
print(as_js_literal)
# Out:
# <div id="highcharts_target_div_ND587T" style="width:100%; height:400;"></div>
# None
# document.addEventListener('DOMContentLoaded', function() {
# Highcharts.chart(null,
# {
#   accessibility: {
#   description: 'We see how temperatures are warmer during the day, especially from around 9am to 9pm. May 8th through 11th are also overall colder days compared to the rest. Overall the temperatures range from around -1 degrees C to around 23 degrees C.'
# },
#   chart: {
#   inverted: true,
#   type: 'heatmap'
# },
#   colorAxis: {
#   min: -5,
#   stops: [[0.0,
# '#3060cf'],
# [0.5,
# '#fffbbc'],
# [0.9,
# '#c4463a']]
# },
#   series: [{
#   data: [[Date.UTC(2017, 4, 1),
# 0,
# 1.4],
# [Date.UTC(2017, 4, 1),
# 1,
# 0.9],
# [Date.UTC(2017, 4, 1),
# 2,
# 0.3],
# [Date.UTC(2017, 4, 1),
# 3,
# -0.5],
# [Date.UTC(2017, 4, 1),
# 4,
# -0.5],
# [Date.UTC(2017, 4, 1),
# 5,
# -0.5],
# [Date.UTC(2017, 4, 1),
# 6,
# -0.6],
# [Date.UTC(2017, 4, 1),
# 7,
# -0.2],
# [Date.UTC(2017, 4, 1),
# 8,
# 0.3],
# [Date.UTC(2017, 4, 1),
# 9,
# 4.8],
# [Date.UTC(2017, 4, 1),
# 10,
# 7.1],
# [Date.UTC(2017, 4, 1),
# 11,
# 8.6],
# [Date.UTC(2017, 4, 1),
# 12,
# 9.9],
# [Date.UTC(2017, 4, 1),
# 13,
# 11.2],
# [Date.UTC(2017, 4, 1),
# 14,
# 12.5],
# [Date.UTC(2017, 4, 1),
# 15,
# 13.1],
# [Date.UTC(2017, 4, 1),
# 16,
# 13.4],
# [Date.UTC(2017, 4, 1),
# 17,
# 14.1],
# [Date.UTC(2017, 4, 1),
# 18,
# 14.3],
# [Date.UTC(2017, 4, 1),
# 19,
# 14.2],
# [Date.UTC(2017, 4, 1),
# 20,
# 11.7],
# [Date.UTC(2017, 4, 1),
# 21,
# 7.6],
# [Date.UTC(2017, 4, 1),
# 22,
# 5.8],
# [Date.UTC(2017, 4, 1),
# 23,
# 4.0],
# [Date.UTC(2017, 4, 2),
# 0,
# 3.6],
# [Date.UTC(2017, 4, 2),
# 1,
# 2.6],
# [Date.UTC(2017, 4, 2),
# 2,
# 1.8],
# [Date.UTC(2017, 4, 2),
# 3,
# 1.4],
# [Date.UTC(2017, 4, 2),
# 4,
# 1.1],
# [Date.UTC(2017, 4, 2),
# 5,
# 1.2],
# [Date.UTC(2017, 4, 2),
# 6,
# 1.2],
# [Date.UTC(2017, 4, 2),
# 7,
# 1.8],
# [Date.UTC(2017, 4, 2),
# 8,
# 3.2],
# [Date.UTC(2017, 4, 2),
# 9,
# 6.7],
# [Date.UTC(2017, 4, 2),
# 10,
# 8.6],
# [Date.UTC(2017, 4, 2),
# 11,
# 10.1],
# [Date.UTC(2017, 4, 2),
# 12,
# 11.5],
# [Date.UTC(2017, 4, 2),
# 13,
# 12.8],
# [Date.UTC(2017, 4, 2),
# 14,
# 13.6],
# [Date.UTC(2017, 4, 2),
# 15,
# 14.4],
# [Date.UTC(2017, 4, 2),
# 16,
# 15.4],
# [Date.UTC(2017, 4, 2),
# 17,
# 16.1],
# [Date.UTC(2017, 4, 2),
# 18,
# 16.0],
# [Date.UTC(2017, 4, 2),
# 19,
# 15.1],
# [Date.UTC(2017, 4, 2),
# 20,
# 12.0],
# [Date.UTC(2017, 4, 2),
# 21,
# 8.0],
# [Date.UTC(2017, 4, 2),
# 22,
# 5.6],
# [Date.UTC(2017, 4, 2),
# 23,
# 4.4],
# [Date.UTC(2017, 4, 3),
# 0,
# 3.8],
# [Date.UTC(2017, 4, 3),
# 1,
# 3.4],
# [Date.UTC(2017, 4, 3),
# 2,
# 2.2],
# [Date.UTC(2017, 4, 3),
# 3,
# 1.7],
# [Date.UTC(2017, 4, 3),
# 4,
# 2.1],
# [Date.UTC(2017, 4, 3),
# 5,
# 2.0],
# [Date.UTC(2017, 4, 3),
# 6,
# 2.6],
# [Date.UTC(2017, 4, 3),
# 7,
# 3.4],
# [Date.UTC(2017, 4, 3),
# 8,
# 3.6],
# [Date.UTC(2017, 4, 3),
# 9,
# 7.2],
# [Date.UTC(2017, 4, 3),
# 10,
# 9.2],
# [Date.UTC(2017, 4, 3),
# 11,
# 10.4],
# [Date.UTC(2017, 4, 3),
# 12,
# 11.8],
# [Date.UTC(2017, 4, 3),
# 13,
# 12.2],
# [Date.UTC(2017, 4, 3),
# 14,
# 13.7],
# [Date.UTC(2017, 4, 3),
# 15,
# 15.1],
# [Date.UTC(2017, 4, 3),
# 16,
# 15.7],
# [Date.UTC(2017, 4, 3),
# 17,
# 16.4],
# [Date.UTC(2017, 4, 3),
# 18,
# 17.0],
# [Date.UTC(2017, 4, 3),
# 19,
# 17.1],
# [Date.UTC(2017, 4, 3),
# 20,
# 14.8],
# [Date.UTC(2017, 4, 3),
# 21,
# 10.6],
# [Date.UTC(2017, 4, 3),
# 22,
# 7.9],
# [Date.UTC(2017, 4, 3),
# 23,
# 6.6],
# [Date.UTC(2017, 4, 4),
# 0,
# 5.9],
# [Date.UTC(2017, 4, 4),
# 1,
# 4.7],
# [Date.UTC(2017, 4, 4),
# 2,
# 5.0],
# [Date.UTC(2017, 4, 4),
# 3,
# 4.7],
# [Date.UTC(2017, 4, 4),
# 4,
# 3.6],
# [Date.UTC(2017, 4, 4),
# 5,
# 3.1],
# [Date.UTC(2017, 4, 4),
# 6,
# 3.1],
# [Date.UTC(2017, 4, 4),
# 7,
# 4.3],
# [Date.UTC(2017, 4, 4),
# 8,
# 3.7],
# [Date.UTC(2017, 4, 4),
# 9,
# 8.0],
# [Date.UTC(2017, 4, 4),
# 10,
# 10.6],
# [Date.UTC(2017, 4, 4),
# 11,
# 11.6],
# [Date.UTC(2017, 4, 4),
# 12,
# 13.1],
# [Date.UTC(2017, 4, 4),
# 13,
# 14.7],
# [Date.UTC(2017, 4, 4),
# 14,
# 15.3],
# [Date.UTC(2017, 4, 4),
# 15,
# 16.2],
# [Date.UTC(2017, 4, 4),
# 16,
# 16.8],
# [Date.UTC(2017, 4, 4),
# 17,
# 17.6],
# [Date.UTC(2017, 4, 4),
# 18,
# 17.2],
# [Date.UTC(2017, 4, 4),
# 19,
# 16.6],
# [Date.UTC(2017, 4, 4),
# 20,
# 14.4],
# [Date.UTC(2017, 4, 4),
# 21,
# 10.4],
# [Date.UTC(2017, 4, 4),
# 22,
# 8.0],
# [Date.UTC(2017, 4, 4),
# 23,
# 6.5],
# [Date.UTC(2017, 4, 5),
# 0,
# 6.3],
# [Date.UTC(2017, 4, 5),
# 1,
# 5.8],
# [Date.UTC(2017, 4, 5),
# 2,
# 5.3],
# [Date.UTC(2017, 4, 5),
# 3,
# 6.9],
# [Date.UTC(2017, 4, 5),
# 4,
# 6.4],
# [Date.UTC(2017, 4, 5),
# 5,
# 5.6],
# [Date.UTC(2017, 4, 5),
# 6,
# 5.7],
# [Date.UTC(2017, 4, 5),
# 7,
# 6.8],
# [Date.UTC(2017, 4, 5),
# 8,
# 9.1],
# [Date.UTC(2017, 4, 5),
# 9,
# 10.9],
# [Date.UTC(2017, 4, 5),
# 10,
# 11.4],
# [Date.UTC(2017, 4, 5),
# 11,
# 12.8],
# [Date.UTC(2017, 4, 5),
# 12,
# 12.9],
# [Date.UTC(2017, 4, 5),
# 13,
# 14.3],
# [Date.UTC(2017, 4, 5),
# 14,
# 17.1],
# [Date.UTC(2017, 4, 5),
# 15,
# 18.0],
# [Date.UTC(2017, 4, 5),
# 16,
# 18.3],
# [Date.UTC(2017, 4, 5),
# 17,
# 19.2],
# [Date.UTC(2017, 4, 5),
# 18,
# 19.0],
# [Date.UTC(2017, 4, 5),
# 19,
# 18.7],
# [Date.UTC(2017, 4, 5),
# 20,
# 16.7],
# [Date.UTC(2017, 4, 5),
# 21,
# 12.8],
# [Date.UTC(2017, 4, 5),
# 22,
# 10.7],
# [Date.UTC(2017, 4, 5),
# 23,
# 9.1],
# [Date.UTC(2017, 4, 6),
# 0,
# 8.0],
# [Date.UTC(2017, 4, 6),
# 1,
# 7.7],
# [Date.UTC(2017, 4, 6),
# 2,
# 7.0],
# [Date.UTC(2017, 4, 6),
# 3,
# 6.1],
# [Date.UTC(2017, 4, 6),
# 4,
# 6.1],
# [Date.UTC(2017, 4, 6),
# 5,
# 5.6],
# [Date.UTC(2017, 4, 6),
# 6,
# 5.9],
# [Date.UTC(2017, 4, 6),
# 7,
# 6.2],
# [Date.UTC(2017, 4, 6),
# 8,
# 7.0],
# [Date.UTC(2017, 4, 6),
# 9,
# 10.4],
# [Date.UTC(2017, 4, 6),
# 10,
# 12.3],
# [Date.UTC(2017, 4, 6),
# 11,
# 13.5],
# [Date.UTC(2017, 4, 6),
# 12,
# 15.5],
# [Date.UTC(2017, 4, 6),
# 13,
# 16.0],
# [Date.UTC(2017, 4, 6),
# 14,
# 18.5],
# [Date.UTC(2017, 4, 6),
# 15,
# 18.2],
# [Date.UTC(2017, 4, 6),
# 16,
# 19.3],
# [Date.UTC(2017, 4, 6),
# 17,
# 20.3],
# [Date.UTC(2017, 4, 6),
# 18,
# 19.8],
# [Date.UTC(2017, 4, 6),
# 19,
# 19.9],
# [Date.UTC(2017, 4, 6),
# 20,
# 16.1],
# [Date.UTC(2017, 4, 6),
# 21,
# 13.1],
# [Date.UTC(2017, 4, 6),
# 22,
# 11.1],
# [Date.UTC(2017, 4, 6),
# 23,
# 9.3],
# [Date.UTC(2017, 4, 7),
# 0,
# 8.8],
# [Date.UTC(2017, 4, 7),
# 1,
# 7.4],
# [Date.UTC(2017, 4, 7),
# 2,
# 7.5],
# [Date.UTC(2017, 4, 7),
# 3,
# 7.2],
# [Date.UTC(2017, 4, 7),
# 4,
# 5.9],
# [Date.UTC(2017, 4, 7),
# 5,
# 5.4],
# [Date.UTC(2017, 4, 7),
# 6,
# 5.6],
# [Date.UTC(2017, 4, 7),
# 7,
# 5.8],
# [Date.UTC(2017, 4, 7),
# 8,
# 7.3],
# [Date.UTC(2017, 4, 7),
# 9,
# 12.4],
# [Date.UTC(2017, 4, 7),
# 10,
# 14.5],
# [Date.UTC(2017, 4, 7),
# 11,
# 14.9],
# [Date.UTC(2017, 4, 7),
# 12,
# 16.7],
# [Date.UTC(2017, 4, 7),
# 13,
# 17.8],
# [Date.UTC(2017, 4, 7),
# 14,
# 18.0],
# [Date.UTC(2017, 4, 7),
# 15,
# 17.9],
# [Date.UTC(2017, 4, 7),
# 16,
# 18.0],
# [Date.UTC(2017, 4, 7),
# 17,
# 17.7],
# [Date.UTC(2017, 4, 7),
# 18,
# 17.1],
# [Date.UTC(2017, 4, 7),
# 19,
# 15.5],
# [Date.UTC(2017, 4, 7),
# 20,
# 12.7],
# [Date.UTC(2017, 4, 7),
# 21,
# 11.1],
# [Date.UTC(2017, 4, 7),
# 22,
# 9.7],
# [Date.UTC(2017, 4, 7),
# 23,
# 8.8],
# [Date.UTC(2017, 4, 8),
# 0,
# 8.5],
# [Date.UTC(2017, 4, 8),
# 1,
# 7.8],
# [Date.UTC(2017, 4, 8),
# 2,
# 6.6],
# [Date.UTC(2017, 4, 8),
# 3,
# 5.7],
# [Date.UTC(2017, 4, 8),
# 4,
# 5.6],
# [Date.UTC(2017, 4, 8),
# 5,
# 5.0],
# [Date.UTC(2017, 4, 8),
# 6,
# 3.2],
# [Date.UTC(2017, 4, 8),
# 7,
# 2.9],
# [Date.UTC(2017, 4, 8),
# 8,
# 5.1],
# [Date.UTC(2017, 4, 8),
# 9,
# 7.9],
# [Date.UTC(2017, 4, 8),
# 10,
# 8.9],
# [Date.UTC(2017, 4, 8),
# 11,
# 9.4],
# [Date.UTC(2017, 4, 8),
# 12,
# 10.0],
# [Date.UTC(2017, 4, 8),
# 13,
# 10.6],
# [Date.UTC(2017, 4, 8),
# 14,
# 11.3],
# [Date.UTC(2017, 4, 8),
# 15,
# 11.6],
# [Date.UTC(2017, 4, 8),
# 16,
# 11.8],
# [Date.UTC(2017, 4, 8),
# 17,
# 12.1],
# [Date.UTC(2017, 4, 8),
# 18,
# 11.9],
# [Date.UTC(2017, 4, 8),
# 19,
# 11.1],
# [Date.UTC(2017, 4, 8),
# 20,
# 10.2],
# [Date.UTC(2017, 4, 8),
# 21,
# 8.3],
# [Date.UTC(2017, 4, 8),
# 22,
# 7.0],
# [Date.UTC(2017, 4, 8),
# 23,
# 6.2],
# [Date.UTC(2017, 4, 9),
# 0,
# 5.2],
# [Date.UTC(2017, 4, 9),
# 1,
# 3.0],
# [Date.UTC(2017, 4, 9),
# 2,
# 1.7],
# [Date.UTC(2017, 4, 9),
# 3,
# 0.9],
# [Date.UTC(2017, 4, 9),
# 4,
# 2.6],
# [Date.UTC(2017, 4, 9),
# 5,
# 4.3],
# [Date.UTC(2017, 4, 9),
# 6,
# 3.3],
# [Date.UTC(2017, 4, 9),
# 7,
# 4.7],
# [Date.UTC(2017, 4, 9),
# 8,
# 5.9],
# [Date.UTC(2017, 4, 9),
# 9,
# 6.1],
# [Date.UTC(2017, 4, 9),
# 10,
# 6.5],
# [Date.UTC(2017, 4, 9),
# 11,
# 8.2],
# [Date.UTC(2017, 4, 9),
# 12,
# 8.0],
# [Date.UTC(2017, 4, 9),
# 13,
# 8.2],
# [Date.UTC(2017, 4, 9),
# 14,
# 8.6],
# [Date.UTC(2017, 4, 9),
# 15,
# 8.0],
# [Date.UTC(2017, 4, 9),
# 16,
# 7.8],
# [Date.UTC(2017, 4, 9),
# 17,
# 6.8],
# [Date.UTC(2017, 4, 9),
# 18,
# 6.3],
# [Date.UTC(2017, 4, 9),
# 19,
# 6.4],
# [Date.UTC(2017, 4, 9),
# 20,
# 5.8],
# [Date.UTC(2017, 4, 9),
# 21,
# 5.3],
# [Date.UTC(2017, 4, 9),
# 22,
# 4.7],
# [Date.UTC(2017, 4, 9),
# 23,
# 4.5],
# [Date.UTC(2017, 4, 10),
# 0,
# 3.5],
# [Date.UTC(2017, 4, 10),
# 1,
# 2.5],
# [Date.UTC(2017, 4, 10),
# 2,
# 2.2],
# [Date.UTC(2017, 4, 10),
# 3,
# 1.2],
# [Date.UTC(2017, 4, 10),
# 4,
# 2.1],
# [Date.UTC(2017, 4, 10),
# 5,
# 2.7],
# [Date.UTC(2017, 4, 10),
# 6,
# 2.9],
# [Date.UTC(2017, 4, 10),
# 7,
# 3.4],
# [Date.UTC(2017, 4, 10),
# 8,
# 4.3],
# [Date.UTC(2017, 4, 10),
# 9,
# 5.5],
# [Date.UTC(2017, 4, 10),
# 10,
# 5.9],
# [Date.UTC(2017, 4, 10),
# 11,
# 6.3],
# [Date.UTC(2017, 4, 10),
# 12,
# 6.8],
# [Date.UTC(2017, 4, 10),
# 13,
# 7.5],
# [Date.UTC(2017, 4, 10),
# 14,
# 7.4],
# [Date.UTC(2017, 4, 10),
# 15,
# 7.4],
# [Date.UTC(2017, 4, 10),
# 16,
# 7.6],
# [Date.UTC(2017, 4, 10),
# 17,
# 7.7],
# [Date.UTC(2017, 4, 10),
# 18,
# 7.4],
# [Date.UTC(2017, 4, 10),
# 19,
# 7.1],
# [Date.UTC(2017, 4, 10),
# 20,
# 6.8],
# [Date.UTC(2017, 4, 10),
# 21,
# 6.3],
# [Date.UTC(2017, 4, 10),
# 22,
# 5.4],
# [Date.UTC(2017, 4, 10),
# 23,
# 4.7],
# [Date.UTC(2017, 4, 11),
# 0,
# 4.4],
# [Date.UTC(2017, 4, 11),
# 1,
# 4.4],
# [Date.UTC(2017, 4, 11),
# 2,
# 4.1],
# [Date.UTC(2017, 4, 11),
# 3,
# 3.9],
# [Date.UTC(2017, 4, 11),
# 4,
# 3.3],
# [Date.UTC(2017, 4, 11),
# 5,
# 3.5],
# [Date.UTC(2017, 4, 11),
# 6,
# 3.5],
# [Date.UTC(2017, 4, 11),
# 7,
# 3.8],
# [Date.UTC(2017, 4, 11),
# 8,
# 4.9],
# [Date.UTC(2017, 4, 11),
# 9,
# 6.0],
# [Date.UTC(2017, 4, 11),
# 10,
# 6.7],
# [Date.UTC(2017, 4, 11),
# 11,
# 7.4],
# [Date.UTC(2017, 4, 11),
# 12,
# 8.4],
# [Date.UTC(2017, 4, 11),
# 13,
# 9.6],
# [Date.UTC(2017, 4, 11),
# 14,
# 10.0],
# [Date.UTC(2017, 4, 11),
# 15,
# 10.0],
# [Date.UTC(2017, 4, 11),
# 16,
# 9.9],
# [Date.UTC(2017, 4, 11),
# 17,
# 10.1],
# [Date.UTC(2017, 4, 11),
# 18,
# 10.0],
# [Date.UTC(2017, 4, 11),
# 19,
# 9.7],
# [Date.UTC(2017, 4, 11),
# 20,
# 9.8],
# [Date.UTC(2017, 4, 11),
# 21,
# 8.8],
# [Date.UTC(2017, 4, 11),
# 22,
# 6.2],
# [Date.UTC(2017, 4, 11),
# 23,
# 5.4],
# [Date.UTC(2017, 4, 12),
# 0,
# 4.3],
# [Date.UTC(2017, 4, 12),
# 1,
# 2.7],
# [Date.UTC(2017, 4, 12),
# 2,
# 3.9],
# [Date.UTC(2017, 4, 12),
# 3,
# 3.5],
# [Date.UTC(2017, 4, 12),
# 4,
# 4.8],
# [Date.UTC(2017, 4, 12),
# 5,
# 4.8],
# [Date.UTC(2017, 4, 12),
# 6,
# 5.2],
# [Date.UTC(2017, 4, 12),
# 7,
# 5.6],
# [Date.UTC(2017, 4, 12),
# 8,
# 6.4],
# [Date.UTC(2017, 4, 12),
# 9,
# 7.3],
# [Date.UTC(2017, 4, 12),
# 10,
# 8.1],
# [Date.UTC(2017, 4, 12),
# 11,
# 9.1],
# [Date.UTC(2017, 4, 12),
# 12,
# 9.9],
# [Date.UTC(2017, 4, 12),
# 13,
# 10.4],
# [Date.UTC(2017, 4, 12),
# 14,
# 10.9],
# [Date.UTC(2017, 4, 12),
# 15,
# 11.7],
# [Date.UTC(2017, 4, 12),
# 16,
# 13.1],
# [Date.UTC(2017, 4, 12),
# 17,
# 13.7],
# [Date.UTC(2017, 4, 12),
# 18,
# 13.9],
# [Date.UTC(2017, 4, 12),
# 19,
# 14.1],
# [Date.UTC(2017, 4, 12),
# 20,
# 12.9],
# [Date.UTC(2017, 4, 12),
# 21,
# 10.4],
# [Date.UTC(2017, 4, 12),
# 22,
# 8.2],
# [Date.UTC(2017, 4, 12),
# 23,
# 5.6],
# [Date.UTC(2017, 4, 13),
# 0,
# 4.2],
# [Date.UTC(2017, 4, 13),
# 1,
# 3.5],
# [Date.UTC(2017, 4, 13),
# 2,
# 3.5],
# [Date.UTC(2017, 4, 13),
# 3,
# 3.9],
# [Date.UTC(2017, 4, 13),
# 4,
# 2.9],
# [Date.UTC(2017, 4, 13),
# 5,
# 2.5],
# [Date.UTC(2017, 4, 13),
# 6,
# 2.8],
# [Date.UTC(2017, 4, 13),
# 7,
# 3.8],
# [Date.UTC(2017, 4, 13),
# 8,
# 5.7],
# [Date.UTC(2017, 4, 13),
# 9,
# 9.7],
# [Date.UTC(2017, 4, 13),
# 10,
# 12.2],
# [Date.UTC(2017, 4, 13),
# 11,
# 13.3],
# [Date.UTC(2017, 4, 13),
# 12,
# 12.7],
# [Date.UTC(2017, 4, 13),
# 13,
# 14.0],
# [Date.UTC(2017, 4, 13),
# 14,
# 14.9],
# [Date.UTC(2017, 4, 13),
# 15,
# 16.6],
# [Date.UTC(2017, 4, 13),
# 16,
# 15.8],
# [Date.UTC(2017, 4, 13),
# 17,
# 16.1],
# [Date.UTC(2017, 4, 13),
# 18,
# 15.5],
# [Date.UTC(2017, 4, 13),
# 19,
# 15.2],
# [Date.UTC(2017, 4, 13),
# 20,
# 15.1],
# [Date.UTC(2017, 4, 13),
# 21,
# 13.9],
# [Date.UTC(2017, 4, 13),
# 22,
# 12.5],
# [Date.UTC(2017, 4, 13),
# 23,
# 11.7],
# [Date.UTC(2017, 4, 14),
# 0,
# 10.7],
# [Date.UTC(2017, 4, 14),
# 1,
# 10.4],
# [Date.UTC(2017, 4, 14),
# 2,
# 10.0],
# [Date.UTC(2017, 4, 14),
# 3,
# 9.8],
# [Date.UTC(2017, 4, 14),
# 4,
# 9.3],
# [Date.UTC(2017, 4, 14),
# 5,
# 9.0],
# [Date.UTC(2017, 4, 14),
# 6,
# 9.2],
# [Date.UTC(2017, 4, 14),
# 7,
# 9.8],
# [Date.UTC(2017, 4, 14),
# 8,
# 10.7],
# [Date.UTC(2017, 4, 14),
# 9,
# 12.0],
# [Date.UTC(2017, 4, 14),
# 10,
# 12.7],
# [Date.UTC(2017, 4, 14),
# 11,
# 12.6],
# [Date.UTC(2017, 4, 14),
# 12,
# 12.2],
# [Date.UTC(2017, 4, 14),
# 13,
# 11.9],
# [Date.UTC(2017, 4, 14),
# 14,
# 12.1],
# [Date.UTC(2017, 4, 14),
# 15,
# 12.3],
# [Date.UTC(2017, 4, 14),
# 16,
# 12.0],
# [Date.UTC(2017, 4, 14),
# 17,
# 11.8],
# [Date.UTC(2017, 4, 14),
# 18,
# 11.5],
# [Date.UTC(2017, 4, 14),
# 19,
# 11.1],
# [Date.UTC(2017, 4, 14),
# 20,
# 10.9],
# [Date.UTC(2017, 4, 14),
# 21,
# 10.7],
# [Date.UTC(2017, 4, 14),
# 22,
# 10.2],
# [Date.UTC(2017, 4, 14),
# 23,
# 9.9],
# [Date.UTC(2017, 4, 15),
# 0,
# 9.4],
# [Date.UTC(2017, 4, 15),
# 1,
# 8.9],
# [Date.UTC(2017, 4, 15),
# 2,
# 9.2],
# [Date.UTC(2017, 4, 15),
# 3,
# 8.8],
# [Date.UTC(2017, 4, 15),
# 4,
# 8.2],
# [Date.UTC(2017, 4, 15),
# 5,
# 8.5],
# [Date.UTC(2017, 4, 15),
# 6,
# 8.5],
# [Date.UTC(2017, 4, 15),
# 7,
# 8.9],
# [Date.UTC(2017, 4, 15),
# 8,
# 9.7],
# [Date.UTC(2017, 4, 15),
# 9,
# 10.3],
# [Date.UTC(2017, 4, 15),
# 10,
# 10.5],
# [Date.UTC(2017, 4, 15),
# 11,
# 11.7],
# [Date.UTC(2017, 4, 15),
# 12,
# 12.1],
# [Date.UTC(2017, 4, 15),
# 13,
# 12.2],
# [Date.UTC(2017, 4, 15),
# 14,
# 13.5],
# [Date.UTC(2017, 4, 15),
# 15,
# 15.3],
# [Date.UTC(2017, 4, 15),
# 16,
# 16.3],
# [Date.UTC(2017, 4, 15),
# 17,
# 16.5],
# [Date.UTC(2017, 4, 15),
# 18,
# 17.0],
# [Date.UTC(2017, 4, 15),
# 19,
# 16.8],
# [Date.UTC(2017, 4, 15),
# 20,
# 15.3],
# [Date.UTC(2017, 4, 15),
# 21,
# 13.5],
# [Date.UTC(2017, 4, 15),
# 22,
# 11.3],
# [Date.UTC(2017, 4, 15),
# 23,
# 9.6],
# [Date.UTC(2017, 4, 16),
# 0,
# 9.0],
# [Date.UTC(2017, 4, 16),
# 1,
# 9.2],
# [Date.UTC(2017, 4, 16),
# 2,
# 9.5],
# [Date.UTC(2017, 4, 16),
# 3,
# 10.0],
# [Date.UTC(2017, 4, 16),
# 4,
# 10.1],
# [Date.UTC(2017, 4, 16),
# 5,
# 10.0],
# [Date.UTC(2017, 4, 16),
# 6,
# 9.3],
# [Date.UTC(2017, 4, 16),
# 7,
# 9.2],
# [Date.UTC(2017, 4, 16),
# 8,
# 9.6],
# [Date.UTC(2017, 4, 16),
# 9,
# 10.1],
# [Date.UTC(2017, 4, 16),
# 10,
# 10.7],
# [Date.UTC(2017, 4, 16),
# 11,
# 11.3],
# [Date.UTC(2017, 4, 16),
# 12,
# 11.8],
# [Date.UTC(2017, 4, 16),
# 13,
# 11.7],
# [Date.UTC(2017, 4, 16),
# 14,
# 11.0],
# [Date.UTC(2017, 4, 16),
# 15,
# 10.3],
# [Date.UTC(2017, 4, 16),
# 16,
# 10.9],
# [Date.UTC(2017, 4, 16),
# 17,
# 10.8],
# [Date.UTC(2017, 4, 16),
# 18,
# 10.3],
# [Date.UTC(2017, 4, 16),
# 19,
# 10.2],
# [Date.UTC(2017, 4, 16),
# 20,
# 10.1],
# [Date.UTC(2017, 4, 16),
# 21,
# 10.0],
# [Date.UTC(2017, 4, 16),
# 22,
# 9.9],
# [Date.UTC(2017, 4, 16),
# 23,
# 9.8],
# [Date.UTC(2017, 4, 17),
# 0,
# 9.7],
# [Date.UTC(2017, 4, 17),
# 1,
# 9.6],
# [Date.UTC(2017, 4, 17),
# 2,
# 9.6],
# [Date.UTC(2017, 4, 17),
# 3,
# 9.5],
# [Date.UTC(2017, 4, 17),
# 4,
# 9.4],
# [Date.UTC(2017, 4, 17),
# 5,
# 9.3],
# [Date.UTC(2017, 4, 17),
# 6,
# 9.3],
# [Date.UTC(2017, 4, 17),
# 7,
# 9.5],
# [Date.UTC(2017, 4, 17),
# 8,
# 9.7],
# [Date.UTC(2017, 4, 17),
# 9,
# 9.9],
# [Date.UTC(2017, 4, 17),
# 10,
# 10.9],
# [Date.UTC(2017, 4, 17),
# 11,
# 13.0],
# [Date.UTC(2017, 4, 17),
# 12,
# 13.4],
# [Date.UTC(2017, 4, 17),
# 13,
# 14.4],
# [Date.UTC(2017, 4, 17),
# 14,
# 15.0],
# [Date.UTC(2017, 4, 17),
# 15,
# 16.4],
# [Date.UTC(2017, 4, 17),
# 16,
# 15.1],
# [Date.UTC(2017, 4, 17),
# 17,
# 15.7],
# [Date.UTC(2017, 4, 17),
# 18,
# 16.9],
# [Date.UTC(2017, 4, 17),
# 19,
# 16.6],
# [Date.UTC(2017, 4, 17),
# 20,
# 15.5],
# [Date.UTC(2017, 4, 17),
# 21,
# 14.3],
# [Date.UTC(2017, 4, 17),
# 22,
# 13.0],
# [Date.UTC(2017, 4, 17),
# 23,
# 12.2],
# [Date.UTC(2017, 4, 18),
# 0,
# 11.8],
# [Date.UTC(2017, 4, 18),
# 1,
# 11.2],
# [Date.UTC(2017, 4, 18),
# 2,
# 10.6],
# [Date.UTC(2017, 4, 18),
# 3,
# 10.4],
# [Date.UTC(2017, 4, 18),
# 4,
# 10.3],
# [Date.UTC(2017, 4, 18),
# 5,
# 10.3],
# [Date.UTC(2017, 4, 18),
# 6,
# 10.3],
# [Date.UTC(2017, 4, 18),
# 7,
# 10.3],
# [Date.UTC(2017, 4, 18),
# 8,
# 10.3],
# [Date.UTC(2017, 4, 18),
# 9,
# 10.2],
# [Date.UTC(2017, 4, 18),
# 10,
# 10.4],
# [Date.UTC(2017, 4, 18),
# 11,
# 10.6],
# [Date.UTC(2017, 4, 18),
# 12,
# 10.6],
# [Date.UTC(2017, 4, 18),
# 13,
# 11.0],
# [Date.UTC(2017, 4, 18),
# 14,
# 11.3],
# [Date.UTC(2017, 4, 18),
# 15,
# 12.0],
# [Date.UTC(2017, 4, 18),
# 16,
# 12.1],
# [Date.UTC(2017, 4, 18),
# 17,
# 11.6],
# [Date.UTC(2017, 4, 18),
# 18,
# 11.2],
# [Date.UTC(2017, 4, 18),
# 19,
# 11.4],
# [Date.UTC(2017, 4, 18),
# 20,
# 11.4],
# [Date.UTC(2017, 4, 18),
# 21,
# 11.6],
# [Date.UTC(2017, 4, 18),
# 22,
# 11.4],
# [Date.UTC(2017, 4, 18),
# 23,
# 11.2],
# [Date.UTC(2017, 4, 19),
# 0,
# 11.0],
# [Date.UTC(2017, 4, 19),
# 1,
# 10.7],
# [Date.UTC(2017, 4, 19),
# 2,
# 10.4],
# [Date.UTC(2017, 4, 19),
# 3,
# 10.2],
# [Date.UTC(2017, 4, 19),
# 4,
# 10.0],
# [Date.UTC(2017, 4, 19),
# 5,
# 9.9],
# [Date.UTC(2017, 4, 19),
# 6,
# 10.0],
# [Date.UTC(2017, 4, 19),
# 7,
# 10.1],
# [Date.UTC(2017, 4, 19),
# 8,
# 10.3],
# [Date.UTC(2017, 4, 19),
# 9,
# 10.7],
# [Date.UTC(2017, 4, 19),
# 10,
# 11.3],
# [Date.UTC(2017, 4, 19),
# 11,
# 12.9],
# [Date.UTC(2017, 4, 19),
# 12,
# 14.4],
# [Date.UTC(2017, 4, 19),
# 13,
# 15.4],
# [Date.UTC(2017, 4, 19),
# 14,
# 16.5],
# [Date.UTC(2017, 4, 19),
# 15,
# 17.8],
# [Date.UTC(2017, 4, 19),
# 16,
# 18.8],
# [Date.UTC(2017, 4, 19),
# 17,
# 19.6],
# [Date.UTC(2017, 4, 19),
# 18,
# 20.0],
# [Date.UTC(2017, 4, 19),
# 19,
# 20.3],
# [Date.UTC(2017, 4, 19),
# 20,
# 18.8],
# [Date.UTC(2017, 4, 19),
# 21,
# 14.5],
# [Date.UTC(2017, 4, 19),
# 22,
# 12.1],
# [Date.UTC(2017, 4, 19),
# 23,
# 11.4],
# [Date.UTC(2017, 4, 20),
# 0,
# 10.1],
# [Date.UTC(2017, 4, 20),
# 1,
# 9.6],
# [Date.UTC(2017, 4, 20),
# 2,
# 10.1],
# [Date.UTC(2017, 4, 20),
# 3,
# 9.8],
# [Date.UTC(2017, 4, 20),
# 4,
# 9.4],
# [Date.UTC(2017, 4, 20),
# 5,
# 9.2],
# [Date.UTC(2017, 4, 20),
# 6,
# 9.0],
# [Date.UTC(2017, 4, 20),
# 7,
# 9.5],
# [Date.UTC(2017, 4, 20),
# 8,
# 11.7],
# [Date.UTC(2017, 4, 20),
# 9,
# 15.3],
# [Date.UTC(2017, 4, 20),
# 10,
# 16.6],
# [Date.UTC(2017, 4, 20),
# 11,
# 18.5],
# [Date.UTC(2017, 4, 20),
# 12,
# 20.0],
# [Date.UTC(2017, 4, 20),
# 13,
# 21.3],
# [Date.UTC(2017, 4, 20),
# 14,
# 20.3],
# [Date.UTC(2017, 4, 20),
# 15,
# 22.9],
# [Date.UTC(2017, 4, 20),
# 16,
# 22.0],
# [Date.UTC(2017, 4, 20),
# 17,
# 22.0],
# [Date.UTC(2017, 4, 20),
# 18,
# 23.1],
# [Date.UTC(2017, 4, 20),
# 19,
# 20.4],
# [Date.UTC(2017, 4, 20),
# 20,
# 18.9],
# [Date.UTC(2017, 4, 20),
# 21,
# 16.8],
# [Date.UTC(2017, 4, 20),
# 22,
# 15.3],
# [Date.UTC(2017, 4, 20),
# 23,
# 13.8],
# [Date.UTC(2017, 4, 21),
# 0,
# 13.1],
# [Date.UTC(2017, 4, 21),
# 1,
# 11.7],
# [Date.UTC(2017, 4, 21),
# 2,
# 11.2],
# [Date.UTC(2017, 4, 21),
# 3,
# 11.0],
# [Date.UTC(2017, 4, 21),
# 4,
# 10.6],
# [Date.UTC(2017, 4, 21),
# 5,
# 10.1],
# [Date.UTC(2017, 4, 21),
# 6,
# 9.9],
# [Date.UTC(2017, 4, 21),
# 7,
# 10.1],
# [Date.UTC(2017, 4, 21),
# 8,
# 10.6],
# [Date.UTC(2017, 4, 21),
# 9,
# 11.7],
# [Date.UTC(2017, 4, 21),
# 10,
# 12.3],
# [Date.UTC(2017, 4, 21),
# 11,
# 14.0],
# [Date.UTC(2017, 4, 21),
# 12,
# 14.3],
# [Date.UTC(2017, 4, 21),
# 13,
# 15.5],
# [Date.UTC(2017, 4, 21),
# 14,
# 16.9],
# [Date.UTC(2017, 4, 21),
# 15,
# 16.0],
# [Date.UTC(2017, 4, 21),
# 16,
# 15.7],
# [Date.UTC(2017, 4, 21),
# 17,
# 14.6],
# [Date.UTC(2017, 4, 21),
# 18,
# 12.5],
# [Date.UTC(2017, 4, 21),
# 19,
# 11.6],
# [Date.UTC(2017, 4, 21),
# 20,
# 11.2],
# [Date.UTC(2017, 4, 21),
# 21,
# 11.0],
# [Date.UTC(2017, 4, 21),
# 22,
# 10.7],
# [Date.UTC(2017, 4, 21),
# 23,
# 10.6],
# [Date.UTC(2017, 4, 22),
# 0,
# 10.4],
# [Date.UTC(2017, 4, 22),
# 1,
# 9.5],
# [Date.UTC(2017, 4, 22),
# 2,
# 9.5],
# [Date.UTC(2017, 4, 22),
# 3,
# 9.4],
# [Date.UTC(2017, 4, 22),
# 4,
# 9.6],
# [Date.UTC(2017, 4, 22),
# 5,
# 9.3],
# [Date.UTC(2017, 4, 22),
# 6,
# 9.3],
# [Date.UTC(2017, 4, 22),
# 7,
# 9.2],
# [Date.UTC(2017, 4, 22),
# 8,
# 9.7],
# [Date.UTC(2017, 4, 22),
# 9,
# 10.3],
# [Date.UTC(2017, 4, 22),
# 10,
# 10.7],
# [Date.UTC(2017, 4, 22),
# 11,
# 11.2],
# [Date.UTC(2017, 4, 22),
# 12,
# 11.2],
# [Date.UTC(2017, 4, 22),
# 13,
# 11.3],
# [Date.UTC(2017, 4, 22),
# 14,
# 11.7],
# [Date.UTC(2017, 4, 22),
# 15,
# 11.9],
# [Date.UTC(2017, 4, 22),
# 16,
# 12.3],
# [Date.UTC(2017, 4, 22),
# 17,
# 12.5],
# [Date.UTC(2017, 4, 22),
# 18,
# 12.5],
# [Date.UTC(2017, 4, 22),
# 19,
# 12.5],
# [Date.UTC(2017, 4, 22),
# 20,
# 12.3],
# [Date.UTC(2017, 4, 22),
# 21,
# 12.3],
# [Date.UTC(2017, 4, 22),
# 22,
# 10.3],
# [Date.UTC(2017, 4, 22),
# 23,
# 7.2],
# [Date.UTC(2017, 4, 23),
# 0,
# 5.8],
# [Date.UTC(2017, 4, 23),
# 1,
# 5.5],
# [Date.UTC(2017, 4, 23),
# 2,
# 4.2],
# [Date.UTC(2017, 4, 23),
# 3,
# 4.4],
# [Date.UTC(2017, 4, 23),
# 4,
# 3.9],
# [Date.UTC(2017, 4, 23),
# 5,
# 3.8],
# [Date.UTC(2017, 4, 23),
# 6,
# 3.3],
# [Date.UTC(2017, 4, 23),
# 7,
# 4.1],
# [Date.UTC(2017, 4, 23),
# 8,
# 6.7],
# [Date.UTC(2017, 4, 23),
# 9,
# 9.4],
# [Date.UTC(2017, 4, 23),
# 10,
# 11.3],
# [Date.UTC(2017, 4, 23),
# 11,
# 12.2],
# [Date.UTC(2017, 4, 23),
# 12,
# 13.5],
# [Date.UTC(2017, 4, 23),
# 13,
# 14.9],
# [Date.UTC(2017, 4, 23),
# 14,
# 16.6],
# [Date.UTC(2017, 4, 23),
# 15,
# 17.5],
# [Date.UTC(2017, 4, 23),
# 16,
# 18.1],
# [Date.UTC(2017, 4, 23),
# 17,
# 17.2],
# [Date.UTC(2017, 4, 23),
# 18,
# 16.8],
# [Date.UTC(2017, 4, 23),
# 19,
# 16.4],
# [Date.UTC(2017, 4, 23),
# 20,
# 15.8],
# [Date.UTC(2017, 4, 23),
# 21,
# 14.6],
# [Date.UTC(2017, 4, 23),
# 22,
# 12.5],
# [Date.UTC(2017, 4, 23),
# 23,
# 9.7],
# [Date.UTC(2017, 4, 24),
# 0,
# 8.3],
# [Date.UTC(2017, 4, 24),
# 1,
# 9.1],
# [Date.UTC(2017, 4, 24),
# 2,
# 10.5],
# [Date.UTC(2017, 4, 24),
# 3,
# 9.7],
# [Date.UTC(2017, 4, 24),
# 4,
# 10.8],
# [Date.UTC(2017, 4, 24),
# 5,
# 11.2],
# [Date.UTC(2017, 4, 24),
# 6,
# 10.9],
# [Date.UTC(2017, 4, 24),
# 7,
# 10.7],
# [Date.UTC(2017, 4, 24),
# 8,
# 11.1],
# [Date.UTC(2017, 4, 24),
# 9,
# 11.7],
# [Date.UTC(2017, 4, 24),
# 10,
# 11.6],
# [Date.UTC(2017, 4, 24),
# 11,
# 10.8],
# [Date.UTC(2017, 4, 24),
# 12,
# 11.0],
# [Date.UTC(2017, 4, 24),
# 13,
# 11.4],
# [Date.UTC(2017, 4, 24),
# 14,
# 12.8],
# [Date.UTC(2017, 4, 24),
# 15,
# 12.9],
# [Date.UTC(2017, 4, 24),
# 16,
# 12.2],
# [Date.UTC(2017, 4, 24),
# 17,
# 12.1],
# [Date.UTC(2017, 4, 24),
# 18,
# 11.7],
# [Date.UTC(2017, 4, 24),
# 19,
# 11.9],
# [Date.UTC(2017, 4, 24),
# 20,
# 11.7],
# [Date.UTC(2017, 4, 24),
# 21,
# 11.6],
# [Date.UTC(2017, 4, 24),
# 22,
# 11.3],
# [Date.UTC(2017, 4, 24),
# 23,
# 11.0],
# [Date.UTC(2017, 4, 25),
# 0,
# 10.4],
# [Date.UTC(2017, 4, 25),
# 1,
# 10.2],
# [Date.UTC(2017, 4, 25),
# 2,
# 9.2],
# [Date.UTC(2017, 4, 25),
# 3,
# 8.8],
# [Date.UTC(2017, 4, 25),
# 4,
# 8.6],
# [Date.UTC(2017, 4, 25),
# 5,
# 8.5],
# [Date.UTC(2017, 4, 25),
# 6,
# 8.7],
# [Date.UTC(2017, 4, 25),
# 7,
# 8.7],
# [Date.UTC(2017, 4, 25),
# 8,
# 8.6],
# [Date.UTC(2017, 4, 25),
# 9,
# 8.6],
# [Date.UTC(2017, 4, 25),
# 10,
# 8.8],
# [Date.UTC(2017, 4, 25),
# 11,
# 9.6],
# [Date.UTC(2017, 4, 25),
# 12,
# 10.1],
# [Date.UTC(2017, 4, 25),
# 13,
# 10.7],
# [Date.UTC(2017, 4, 25),
# 14,
# 11.6],
# [Date.UTC(2017, 4, 25),
# 15,
# 12.2],
# [Date.UTC(2017, 4, 25),
# 16,
# 12.6],
# [Date.UTC(2017, 4, 25),
# 17,
# 13.1],
# [Date.UTC(2017, 4, 25),
# 18,
# 13.0],
# [Date.UTC(2017, 4, 25),
# 19,
# 12.6],
# [Date.UTC(2017, 4, 25),
# 20,
# 12.2],
# [Date.UTC(2017, 4, 25),
# 21,
# 12.0],
# [Date.UTC(2017, 4, 25),
# 22,
# 11.5],
# [Date.UTC(2017, 4, 25),
# 23,
# 11.2],
# [Date.UTC(2017, 4, 26),
# 0,
# 10.9],
# [Date.UTC(2017, 4, 26),
# 1,
# 10.8],
# [Date.UTC(2017, 4, 26),
# 2,
# 10.7],
# [Date.UTC(2017, 4, 26),
# 3,
# 10.6],
# [Date.UTC(2017, 4, 26),
# 4,
# 10.6],
# [Date.UTC(2017, 4, 26),
# 5,
# 10.5],
# [Date.UTC(2017, 4, 26),
# 6,
# 10.5],
# [Date.UTC(2017, 4, 26),
# 7,
# 10.6],
# [Date.UTC(2017, 4, 26),
# 8,
# 10.9],
# [Date.UTC(2017, 4, 26),
# 9,
# 11.1],
# [Date.UTC(2017, 4, 26),
# 10,
# 11.3],
# [Date.UTC(2017, 4, 26),
# 11,
# 11.6],
# [Date.UTC(2017, 4, 26),
# 12,
# 11.7],
# [Date.UTC(2017, 4, 26),
# 13,
# 13.0],
# [Date.UTC(2017, 4, 26),
# 14,
# 13.8],
# [Date.UTC(2017, 4, 26),
# 15,
# 14.5],
# [Date.UTC(2017, 4, 26),
# 16,
# 16.1],
# [Date.UTC(2017, 4, 26),
# 17,
# 14.9],
# [Date.UTC(2017, 4, 26),
# 18,
# 14.8],
# [Date.UTC(2017, 4, 26),
# 19,
# 14.5],
# [Date.UTC(2017, 4, 26),
# 20,
# 14.1],
# [Date.UTC(2017, 4, 26),
# 21,
# 13.6],
# [Date.UTC(2017, 4, 26),
# 22,
# 12.9],
# [Date.UTC(2017, 4, 26),
# 23,
# 12.5],
# [Date.UTC(2017, 4, 27),
# 0,
# 12.0],
# [Date.UTC(2017, 4, 27),
# 1,
# 12.0],
# [Date.UTC(2017, 4, 27),
# 2,
# 11.9],
# [Date.UTC(2017, 4, 27),
# 3,
# 11.9],
# [Date.UTC(2017, 4, 27),
# 4,
# 11.7],
# [Date.UTC(2017, 4, 27),
# 5,
# 11.4],
# [Date.UTC(2017, 4, 27),
# 6,
# 10.7],
# [Date.UTC(2017, 4, 27),
# 7,
# 10.3],
# [Date.UTC(2017, 4, 27),
# 8,
# 12.4],
# [Date.UTC(2017, 4, 27),
# 9,
# 13.4],
# [Date.UTC(2017, 4, 27),
# 10,
# 13.9],
# [Date.UTC(2017, 4, 27),
# 11,
# 15.5],
# [Date.UTC(2017, 4, 27),
# 12,
# 15.9],
# [Date.UTC(2017, 4, 27),
# 13,
# 17.8],
# [Date.UTC(2017, 4, 27),
# 14,
# 19.7],
# [Date.UTC(2017, 4, 27),
# 15,
# 20.6],
# [Date.UTC(2017, 4, 27),
# 16,
# 22.0],
# [Date.UTC(2017, 4, 27),
# 17,
# 22.3],
# [Date.UTC(2017, 4, 27),
# 18,
# 22.3],
# [Date.UTC(2017, 4, 27),
# 19,
# 21.8],
# [Date.UTC(2017, 4, 27),
# 20,
# 20.7],
# [Date.UTC(2017, 4, 27),
# 21,
# 17.2],
# [Date.UTC(2017, 4, 27),
# 22,
# 15.3],
# [Date.UTC(2017, 4, 27),
# 23,
# 13.7],
# [Date.UTC(2017, 4, 28),
# 0,
# 12.4],
# [Date.UTC(2017, 4, 28),
# 1,
# 11.9],
# [Date.UTC(2017, 4, 28),
# 2,
# 10.8],
# [Date.UTC(2017, 4, 28),
# 3,
# 10.4],
# [Date.UTC(2017, 4, 28),
# 4,
# 9.4],
# [Date.UTC(2017, 4, 28),
# 5,
# 9.3],
# [Date.UTC(2017, 4, 28),
# 6,
# 9.0],
# [Date.UTC(2017, 4, 28),
# 7,
# 11.3],
# [Date.UTC(2017, 4, 28),
# 8,
# 13.1],
# [Date.UTC(2017, 4, 28),
# 9,
# 14.0],
# [Date.UTC(2017, 4, 28),
# 10,
# 15.1],
# [Date.UTC(2017, 4, 28),
# 11,
# 16.1],
# [Date.UTC(2017, 4, 28),
# 12,
# 16.8],
# [Date.UTC(2017, 4, 28),
# 13,
# 15.7],
# [Date.UTC(2017, 4, 28),
# 14,
# 16.4],
# [Date.UTC(2017, 4, 28),
# 15,
# 15.1],
# [Date.UTC(2017, 4, 28),
# 16,
# 17.0],
# [Date.UTC(2017, 4, 28),
# 17,
# 17.8],
# [Date.UTC(2017, 4, 28),
# 18,
# 17.6],
# [Date.UTC(2017, 4, 28),
# 19,
# 18.2],
# [Date.UTC(2017, 4, 28),
# 20,
# 17.4],
# [Date.UTC(2017, 4, 28),
# 21,
# 15.8],
# [Date.UTC(2017, 4, 28),
# 22,
# 15.7],
# [Date.UTC(2017, 4, 28),
# 23,
# 15.4],
# [Date.UTC(2017, 4, 29),
# 0,
# 14.5],
# [Date.UTC(2017, 4, 29),
# 1,
# 12.6],
# [Date.UTC(2017, 4, 29),
# 2,
# 12.3],
# [Date.UTC(2017, 4, 29),
# 3,
# 12.9],
# [Date.UTC(2017, 4, 29),
# 4,
# 12.5],
# [Date.UTC(2017, 4, 29),
# 5,
# 12.5],
# [Date.UTC(2017, 4, 29),
# 6,
# 12.5],
# [Date.UTC(2017, 4, 29),
# 7,
# 12.9],
# [Date.UTC(2017, 4, 29),
# 8,
# 13.0],
# [Date.UTC(2017, 4, 29),
# 9,
# 13.1],
# [Date.UTC(2017, 4, 29),
# 10,
# 13.0],
# [Date.UTC(2017, 4, 29),
# 11,
# 13.0],
# [Date.UTC(2017, 4, 29),
# 12,
# 13.1],
# [Date.UTC(2017, 4, 29),
# 13,
# 13.0],
# [Date.UTC(2017, 4, 29),
# 14,
# 13.4],
# [Date.UTC(2017, 4, 29),
# 15,
# 14.8],
# [Date.UTC(2017, 4, 29),
# 16,
# 14.5],
# [Date.UTC(2017, 4, 29),
# 17,
# 14.6],
# [Date.UTC(2017, 4, 29),
# 18,
# 15.6],
# [Date.UTC(2017, 4, 29),
# 19,
# 15.2],
# [Date.UTC(2017, 4, 29),
# 20,
# 14.7],
# [Date.UTC(2017, 4, 29),
# 21,
# 14.1],
# [Date.UTC(2017, 4, 29),
# 22,
# 12.6],
# [Date.UTC(2017, 4, 29),
# 23,
# 12.3],
# [Date.UTC(2017, 4, 30),
# 0,
# 12.7],
# [Date.UTC(2017, 4, 30),
# 1,
# 12.8],
# [Date.UTC(2017, 4, 30),
# 2,
# 12.7],
# [Date.UTC(2017, 4, 30),
# 3,
# 12.7],
# [Date.UTC(2017, 4, 30),
# 4,
# 12.5],
# [Date.UTC(2017, 4, 30),
# 5,
# 12.6],
# [Date.UTC(2017, 4, 30),
# 6,
# 12.5],
# [Date.UTC(2017, 4, 30),
# 7,
# 12.7],
# [Date.UTC(2017, 4, 30),
# 8,
# 12.8],
# [Date.UTC(2017, 4, 30),
# 9,
# 13.0],
# [Date.UTC(2017, 4, 30),
# 10,
# 13.0],
# [Date.UTC(2017, 4, 30),
# 11,
# 12.9],
# [Date.UTC(2017, 4, 30),
# 12,
# 12.8],
# [Date.UTC(2017, 4, 30),
# 13,
# 12.7],
# [Date.UTC(2017, 4, 30),
# 14,
# 13.0],
# [Date.UTC(2017, 4, 30),
# 15,
# 13.4],
# [Date.UTC(2017, 4, 30),
# 16,
# 13.0],
# [Date.UTC(2017, 4, 30),
# 17,
# 13.9],
# [Date.UTC(2017, 4, 30),
# 18,
# 14.5],
# [Date.UTC(2017, 4, 30),
# 19,
# 16.0],
# [Date.UTC(2017, 4, 30),
# 20,
# 16.3],
# [Date.UTC(2017, 4, 30),
# 21,
# 13.6],
# [Date.UTC(2017, 4, 30),
# 22,
# 13.1],
# [Date.UTC(2017, 4, 30),
# 23,
# 12.5],
# [Date.UTC(2017, 4, 31),
# 0,
# 11.8],
# [Date.UTC(2017, 4, 31),
# 1,
# 10.5],
# [Date.UTC(2017, 4, 31),
# 2,
# 9.9],
# [Date.UTC(2017, 4, 31),
# 3,
# 10.8],
# [Date.UTC(2017, 4, 31),
# 4,
# 11.1],
# [Date.UTC(2017, 4, 31),
# 5,
# 11.0],
# [Date.UTC(2017, 4, 31),
# 6,
# 10.7],
# [Date.UTC(2017, 4, 31),
# 7,
# 11.0],
# [Date.UTC(2017, 4, 31),
# 8,
# 11.1],
# [Date.UTC(2017, 4, 31),
# 9,
# 11.1],
# [Date.UTC(2017, 4, 31),
# 10,
# 10.7],
# [Date.UTC(2017, 4, 31),
# 11,
# 10.8],
# [Date.UTC(2017, 4, 31),
# 12,
# 11.7],
# [Date.UTC(2017, 4, 31),
# 13,
# 11.6],
# [Date.UTC(2017, 4, 31),
# 14,
# 11.9],
# [Date.UTC(2017, 4, 31),
# 15,
# 12.5],
# [Date.UTC(2017, 4, 31),
# 16,
# 13.6],
# [Date.UTC(2017, 4, 31),
# 17,
# 12.6],
# [Date.UTC(2017, 4, 31),
# 18,
# 11.5],
# [Date.UTC(2017, 4, 31),
# 19,
# 12.2],
# [Date.UTC(2017, 4, 31),
# 20,
# 12.5],
# [Date.UTC(2017, 4, 31),
# 21,
# 11.1],
# [Date.UTC(2017, 4, 31),
# 22,
# 10.7],
# [Date.UTC(2017, 4, 31),
# 23,
# 10.3]],
#   name: 'Time',
#   colsize: 86400000,
#   accessibility: {
#   enabled: false
# },
#   tooltip: {
#   headerFormat: 'Temperature<br/>',
#   pointFormat: '{point.x:%e %b, %Y} {point.y}:00: <b>{point.value} ℃</b>'
# },
#   type: 'heatmap'
# }],
#   subtitle: {
#   align: 'left',
#   text: 'Temperature variation by day and hour through May 2017'
# },
#   title: {
#   align: 'left',
#   text: 'Highcharts Heat Map'
# },
#   xAxis: {
#   labels: {
#   enabled: true,
#   format: {value:%Y-%m-%d}
# },
#   max: Date.UTC(2017, 4, 31),
#   min: Date.UTC(2017, 4, 1),
#   tickPixelInterval: 50
# },
#   yAxis: {
#   accessibility: {
#   description: 'Hours in the day'
# },
#   endOnTick: false,
#   labels: {
#   format: '{value}:00'
# },
#   max: 23,
#   maxPadding: 0,
#   min: 0,
#   minPadding: 0,
#   startOnTick: false,
#   tickPositions: [0,
# 6,
# 12,
# 18,
# 24],
#   tickWidth: 1,
#   title: {
#   text: null
# }
# }
# },
# );
# });

# %%
#my_png_image = chart.download_chart(format = 'png',  filename = 'my-chart-file.png')
#my_png_image = chart.download_chart(format = 'png', timeout=120.0)
